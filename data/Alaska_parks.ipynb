# %%
import pandas as pd

# %%
alaska = 'nps_df.csv'
alaska_df = pd.read_csv(alaska)

# %%
alaska_df.head(52)
# Out:
#    park_code                               national_park           state  \
# 0       ACAD                        Acadia National Park           Maine
# 1       ARCH                        Arches National Park            Utah
# 2       BADL                      Badlands National Park    South Dakota
# 3       BIBE                      Big Bend National Park           Texas
# 4       BISC                      Biscayne National Park         Florida
# 5       BLCA  Black Canyon of the Gunnison National Park        Colorado
# 6       BRCA                  Bryce Canyon National Park            Utah
# 7       CANY                   Canyonlands National Park            Utah
# 8       CARE                  Capitol Reef National Park            Utah
# 9       CAVE              Carlsbad Caverns National Park      New Mexico
# 10      CHIS               Channel Islands National Park      California
# 11      CONG                      Congaree National Park  South Carolina
# ...

# %%
unique_state = alaska_df["park_code"].unique()
unique_state
# Out:
# array(['DENA', 'GAAR', 'GLBA', 'KATM', 'KEFJ', 'KOVA', 'LACL', 'WRST'],
#       dtype=object)

# %%
alaska_df = alaska_df.loc[alaska_df["state"] == "Alaska", :]
alaska_df.head(7)
# Out:
#    park_code                      national_park   state    acres  latitude  \
# 14      DENA               Denali National Park  Alaska  3372402     63.33
# 18      GAAR  Gates of the Arctic National Park  Alaska  7523898     67.78
# 20      GLBA          Glacier Bay National Park  Alaska  3224840     58.50
# 32      KATM               Katmai National Park  Alaska  3674530     58.50
# 33      KEFJ         Kenai Fjords National Park  Alaska   669983     59.92
# 34      KOVA         Kobuk Valley National Park  Alaska  1750717     67.55
# 35      LACL           Lake Clark National Park  Alaska  2619733     60.97
#
#     longitude
# 14    -150.50
# 18    -153.30
# 20    -137.00
# 32    -155.00
# 33    -149.65
# 34    -159.28
# 35    -153.42

# %%
national_parks = alaska_df.copy()
del national_parks['acres']
del national_parks['state']
national_parks
# Out:
#    park_code                      national_park  latitude  longitude
# 14      DENA               Denali National Park     63.33    -150.50
# 18      GAAR  Gates of the Arctic National Park     67.78    -153.30
# 20      GLBA          Glacier Bay National Park     58.50    -137.00
# 32      KATM               Katmai National Park     58.50    -155.00
# 33      KEFJ         Kenai Fjords National Park     59.92    -149.65
# 34      KOVA         Kobuk Valley National Park     67.55    -159.28
# 35      LACL           Lake Clark National Park     60.97    -153.42
# 52      WRST  Wrangell - St Elias National Park     61.00    -142.00

# %%
national_parks.to_csv('Alaska_parks.csv')
